# %%
import pandas as pd

produto_df = pd.read_excel("C:/Users/polez/Documents/Provence_Festas/dados/estoque.xlsx")
display(produto_df)
# Out:
#                                                Código  \
# 0                                             8 / 691
# 1                                             8 / 109
# 2                                              R / 26
# 3                                             5 / 893
# 4                                             3 / 824
# ...                                               ...
# 1670                                          2 / 332
# 1671                                          2 / 124
# 1672                                           881913
# 1673                                           847764
# 1674  Valor Total de Locação dos Itens: R$ 260.253,17
#
#                                           Fornecedor  \
# 0                                              Geral
# 1                                              Geral
# 2                                              Geral
# 3                                              Geral
# ...
