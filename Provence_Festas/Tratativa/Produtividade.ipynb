# %%
import pandas as pd

Produtividade_df = pd.read_excel("C:/Users/polez/Documents/Provence_Festas/dados/2023/RelatorioProdutividade.xlsx")

Produtividade_df.rename(columns={'ID Ped.': 'Id Pedido', 'Data da festa' : 'Data Evento', 'Cód. prod. / Descrição / Qtde' : 'Descricao'}, inplace = True)

Produtividade_df.fillna(method = 'ffill')

df_filtro = Produtividade_df[Produtividade_df['Status']=='Locação']

# %%
# Produtividade_df['Data Evento'].astype('datetime64[ns]')

# Produtividade_df['Data Evento']= pd.to_datetime(Produtividade_df['Data Evento'])

# %%
# Produtividade_df = pd.DataFrame(Produtividade_df,columns=["ID Pedido"])


# Produtividade_df['Descricao'].iloc[:-1]
# Produtividade_df["Desc"] = Produtividade_df["Descricao"].str.split('/').str[1]

df_filtro['Codigo'] = df_filtro['Descricao'].str.split('/').str[0]

df_filtro['Des'] = df_filtro['Descricao'].str.split(' / ').str[1]

df_filtro['QTD'] = df_filtro['Descricao'].str.split('/').str[-1]

# df_filtro.fillna(method = 'ffill')

df_filtro
# Out:
# C:\Users\polez\AppData\Local\Temp/ipykernel_15552/1242419517.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtro['Codigo'] = df_filtro['Descricao'].str.split('/').str[0]
# C:\Users\polez\AppData\Local\Temp/ipykernel_15552/1242419517.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtro['Des'] = df_filtro['Descricao'].str.split(' / ').str[1]
# C:\Users\polez\AppData\Local\Temp/ipykernel_15552/1242419517.py:11: SettingWithCopyWarning:
# ...

# %%
# determining the name of the file
file_name = 'produtividade.xlsx'
  
# saving the excel
Produtividade_df.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.
