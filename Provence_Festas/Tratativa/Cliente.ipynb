# %%
import pandas as pd
import numpy as np

cliente = pd.read_excel('C:/Users/polez/Documents/Provence_Festas/dados/Clientes2023.xlsx')

cliente_df = pd.DataFrame(cliente)

cliente_df.columns = ["ID", "Nome", "Sexo", "Data Nascimento", "CPF_CNPJ", "RG", "Telefone", "Celular", "Endereco", 
                 "Profissao", "Data Cadastro", "Onde Conheceu", "Desconto", "Facebook", "Observacao", "Emailx", 
                 "Emaily", "Email"]

# cliente_df.info()

cliente_df.dropna(subset = ['Nome'], inplace = True)

cliente_df = cliente_df.fillna({'CPF_CNPJ': '0', 'RG': '0', 'Telefone': '0', 'Celular': '0', 'Endereco': '0', 'Data Cadastro': '0', 
                                'Email': '0', 'Observacao': '0'})


display(cliente_df[['ID', 'Nome', 'CPF_CNPJ', 'RG', 'Telefone', 'Celular', 'Endereco', 'Data Cadastro','Email']])

cliente_df.info()
# Out:
#         ID                                        Nome            CPF_CNPJ  \
# 0     2340                    *andressa Barbosa Pareja      406.559.418-94
# 1     2190                              Anderson Souza      672.398.976-72
# 2     2413                                Luciana Vivo                   0
# 3     2459                    Lui Home ( C.g.lui- Me )  14.514.922/0001-21
# 4     2207  Pfb Digital Importação E Exportação Eirele  37.568.861/0002-61
# ...    ...                                         ...                 ...
# 3415  1597                        Zaqueu Silva Andrade                   0
# 3416  2116                    Zenilda Soprani Da Silva      640.069.809-49
# 3417  2710                     Zilda Derrico De Castro      764.803.808-00
# 3418  2831                       Zoraide Mendes Artave      023.375.838-05
# 3419  2787                           Zuni Gastronomia   27.616.071/0001-70
#
#             RG        Telefone                           Celular  \
# ...
