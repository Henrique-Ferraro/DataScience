# %% [markdown]
# # Automação Relatorios - Provence Festas
#
# #### Desafio:
#
# Trabalhamos em uma empresa de locação de material para festas e precisamos pegar na internet, de forma automática, o inventario e precisamos tratar a planilha e enviar por email para o responsável.
#
# Para isso, vamos criar uma automação web:
#
# - Usaremos o selenium
# - Importante: baixar o webdriver

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.alert import Alert
import pyautogui
import pyperclip
import datetime

import time

# %%
#para rodar o chrome em 2º plano
# from selenium.webdriver.chrome.options import Options
# chrome_options = Options()
# chrome_options.headless = True 
# navegador = webdriver.Chrome(options=chrome_options)


# ABRINDO O NAVEGADOR

navegador = webdriver.Chrome()

navegador.get("http://provencefestas.slapfestas.com.br//")


# DIGITANDO LOGIN E SENHA
    
#alert = navegador.find_element(By.XPATH,
    #'//*[@id="alertMsg"]/div/div')

login = navegador.find_element(By.XPATH,
    '//*[@id="login"]/div/div[2]/form/div[1]/input').send_keys("Provencefestas")

time.sleep(1)

senha = navegador.find_element(By.XPATH,
    '//*[@id="login"]/div/div[2]/form/div[2]/input').send_keys("hctf86")

time.sleep(1)

# Clicando em entrar
entrar = navegador.find_element(By.XPATH,
    '//*[@id="login"]/div/div[2]/form/div[4]/div[1]/button').send_keys(Keys.ENTER)

# Fechando Alerta de Janela sendo utilizada em outro dispositivo
navegador.find_element(By.XPATH,
    '//*[@id="alertMsg"]/div/div/form/button').send_keys(Keys.ENTER)

time.sleep(2)

# Fechando Alerta de Catalogo
navegador.find_element(By.XPATH,
    '//*[@id="step-0"]/div[3]/button[3]').send_keys(Keys.ENTER)


# ABRINDO O RELATÓRIO DE CLIENTE

relatorios = navegador.find_element(By.XPATH,
    '//*[@id="relatorios"]/a').click()

cliente = navegador.find_element(By.CSS_SELECTOR,
    "a#relatorio_cliente")
cliente.click()

time.sleep(1)

radioAmbos = navegador.find_element(By.XPATH,
    '//*[@id="ambos"]').click()

seletorTipo = navegador.find_element(By.XPATH,
    '//*[@id="tipo"]]').click()

seletorTipoTodos = navegador.find_element(By.XPATH,
    '//*[@id="tipo"]').send_keys("Todos")

seletorFormato = navegador.find_element(By.XPATH,
    '//*[@id="format"]').send_keys("Excel")

pesquisar = navegador.find_element(By.XPATH,
    '//*[@id="consulta"]/i').click()



# ABRINDO O RELATÓRIO DE PRODUTO

# ConsultaProduto = navegador.find_element(By.XPATH,
#     '//*[@id="step-0"]/div[3]/button[3]').click()

# produtos = navegador.find_element(By.XPATH,
#     '//*[@id="alterar_produto"]').send_keys(Keys.ENTER)

# time.sleep(1)

# fechandoPopup = navegador.find_element(By.XPATH,
#     '//*[@id="step-0"]/div[3]/button[3]').send_keys(Keys.ENTER)

# # BAIXANDO O RELATÓRIO PRODUTO

# bxrelat = navegador.find_element(By.XPATH,
#     '//*[@id="filtroColunas"]').send_keys(Keys.ENTER)

# time.sleep(1)

# barraform = navegador.find_element(By.XPATH,
#     '//*[@id="formDownloadEstoque"]/div[2]/div').click()

# time.sleep(1)

# formato = navegador.find_element(By.XPATH,
#     '//*[@id="formDownloadEstoque"]/div[2]/div/label[3]/input').click()

# time.sleep(1)

# barravalor = navegador.find_element(By.XPATH,
#     '//*[@id="formDownloadEstoque"]/div[3]/div').click()

# time.sleep(1)

# valorcom = navegador.find_element(By.XPATH,
#     '//*[@id="formDownloadEstoque"]/div[3]/div/div/label[2]/input').click()


# time.sleep(1)

# valorrep = navegador.find_element(By.XPATH,
#     '//*[@id="formDownloadEstoque"]/div[3]/div/div/label[3]/input').click()

# time.sleep(1)

# export = navegador.find_element(By.XPATH,
#     '//*[@id="formDownloadEstoque"]/div[5]/button').send_keys(Keys.ENTER)

# time.sleep(5)


# # ABRINDO O RELATÓRIO DE PRODUTIVIDADE

# relatorio = navegador.find_element(By.XPATH,
#     '//*[@id="relatoriosMenuPai"]').click()

# time.sleep(1)

# relProdutividade = navegador.find_element(By.XPATH,
#     '//*[@id="relatorio_produtivid"]').click()

# time.sleep(1)

# fechandoPopup = navegador.find_element(By.XPATH,
#     '//*[@id="step-0"]/div[3]/button[3]').click()

# time.sleep(1)

# operador = navegador.find_element(By.XPATH,
#      '//*[@id="buscar"]').send_keys("Todos")

# # BAIXANDO O RELATÓRIO PRODUTO

# radioFrete = navegador.find_element(By.XPATH,
#     '//*[@id="ambos"]').click()

# time.sleep(1)

# status = navegador.find_element(By.XPATH,
#      '//*[@id="status"]').send_keys("Todos")

# time.sleep(1)


# dataInicial = navegador.find_element(By.NAME,
#      'dataInicial').click()

# navegador.find_element(By.NAME,
#      'dataInicial').send_keys("01/01/2019")

# navegador.find_element(By.NAME,
#     'dataInicial').send_keys(Keys.ENTER)

# time.sleep(2)

# formato = navegador.find_element(By.XPATH,
#     '//*[@id="format"]').send_keys("Excel")

# time.sleep(1)

# dataFinal = navegador.find_element(By.NAME,
#      'dataFinal').click()

# navegador.find_element(By.NAME,
#      'dataFinal').send_keys("20/03/2023")


# botaoGerarRelatorio = navegador.find_element(By.XPATH,
#     '//*[@id="cadastro"]/div/div[7]/div/button').send_keys(Keys.ENTER)

# time.sleep(10)

navegador.quit()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[4], line 10
#       1 #para rodar o chrome em 2º plano
#       2 # from selenium.webdriver.chrome.options import Options
#       3 # chrome_options = Options()
#    (...)
#       7
#       8 # ABRINDO O NAVEGADOR
# ---> 10 navegador = webdriver.Chrome()
#      12 navegador.get("http://provencefestas.slapfestas.com.br//")
#      15 # DIGITANDO LOGIN E SENHA
#      16
#      17 #alert = navegador.find_element(By.XPATH,
#      18     #'//*[@id="alertMsg"]/div/div')
#
# File c:\Users\polez\Documents\Provence_Festas\Automacao\.venv\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:80, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      77 if not service:
# ...

# %%
# ABRINDO O NAVEGADOR

navegador = webdriver.Chrome()

navegador.get("http://provencefestas.slapfestas.com.br//")


# DIGITANDO LOGIN E SENHA

login = navegador.find_element(By.XPATH,
    '//*[@id="login"]/div/div[2]/form/div[1]/input').send_keys("Provencefestas")

time.sleep(1)

senha = navegador.find_element(By.XPATH,
    '//*[@id="login"]/div/div[2]/form/div[2]/input').send_keys("hctf86")

time.sleep(1)

# Fechando Alerta de Janela sendo utilizada em outro dispositivo
navegador.find_element(By.XPATH,
    '//*[@id="login"]/div/div[2]/form/div[4]/div[1]/button').send_keys(Keys.ENTER)

# Fechando Alerta de informativo
navegador.find_element(By.XPATH,
    '//*[@id="alertMsg"]/div/div/form/button').send_keys(Keys.ENTER)

time.sleep(2)

navegador.find_element(By.XPATH,
    '//*[@id="step-0"]/div[3]/button[3]').send_keys(Keys.ENTER)



# # ABRINDO O RELATÓRIO DE ENTREGA POR MÊS

# Clicando no modulo relatorios
relatorio = navegador.find_element(By.XPATH,
    '//*[@id="relatoriosMenuPai"]').click()

time.sleep(1)

# Selecionando a opção Entregas por mês
entregasMes = navegador.find_element(By.CLASS_NAME,
    'glyphicon glyphicon-file').send_keys(Keys.ENTER)

time.sleep(1)

msgUsuarioLogado = navegador.find_element(By.XPATH,
    '/html/body/div[20]/div/div[6]/button[1]').click()

time.sleep(1)

# Selecionando o Mês
buscaMesAno = navegador.find_element(By.XPATH,
    '//*[@id="mes"]').send_keys("Todos")

time.sleep(1)

# Selecionando o Frete
buscarFrete = navegador.find_element(By.XPATH,
     '//*[@id="frete"]').send_keys("Todos")

time.sleep(1)

# Selecionando o Ano
buscarAno = navegador.find_element(By.XPATH,
    '//*[@id="ano"]').send_keys("2019")

time.sleep(1)

# Clicando no Buscar
buscar = navegador.find_element(By.XPATH,
     '//*[@id="signup"]').click()

time.sleep(2)

navegador.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[10], line 44
#      41 time.sleep(1)
#      43 # Selecionando a opção Entregas por mês
# ---> 44 entregasMes = navegador.find_element(By.CLASS_NAME,
#      45     'glyphicon glyphicon-file').send_keys(Keys.ENTER)
#      47 time.sleep(1)
#      49 msgUsuarioLogado = navegador.find_element(By.XPATH,
#      50     '/html/body/div[20]/div/div[6]/button[1]').click()
#
# File c:\Users\polez\Documents\Provence_Festas\Automacao\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     827     by = By.CSS_SELECTOR
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %% [markdown]
# ### Agora vamos formatar a nossa base de produtos

# %% [markdown]
# - Importando a base de dados

# %%
# Passo 1: Importar a base de dados
import pandas as pd

estoque_df = pd.read_excel(r'C:/Users/polez/Downloads/estoque.xlsx')
#display(estoque_df)

# Passo 2: Visualizar a base de dados
estoque_df = estoque_df.drop(["Fornecedor", "Cor", "Tamanho", "Descrição", "Valor de Compra", "Valor Unitário", "Valor de Reposição"], axis=1)

estoque_df['QTD'] = ""
estoque_df['Data'] = ""

estoque_df.rename(columns={'Código': 'Cod', 'Nome do Produto': 'Produto', 'Quantidade': 'QTD_Itens'}, inplace = True)
display(estoque_df.loc[estoque_df['Categoria']!='Terceiros'])


#df_new = pd.DataFrame(df_estoque[['Cod', 'Categoria', 'Produto', 'QTD_Itens', 'QTD', 'Data']])
estoque_df.Categoria.value_counts()

# df_new.dtypes
display(estoque_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 4
#       1 # Passo 1: Importar a base de dados
#       2 import pandas as pd
# ----> 4 estoque_df = pd.read_excel(r'C:/Users/polez/Downloads/estoque.xlsx')
#       5 #display(estoque_df)
#       6
#       7 # Passo 2: Visualizar a base de dados
#       8 estoque_df = estoque_df.drop(["Fornecedor", "Cor", "Tamanho", "Descrição", "Valor de Compra", "Valor Unitário", "Valor de Reposição"], axis=1)
#
# File c:\Users\polez\Documents\Provence_Festas\Automacao\.venv\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
display(estoque_df.loc[estoque_df['Categoria']=='Terceiros'])
# Out:
#           Cod                                     Produto  QTD_Itens  \
# 61    T / 001                   Anel Guarda Suculenta (3)      147.0
# 105   T / 001      Banco de Madeira 2 C x 30 L x 45 A (3)        1.0
# 132   T / 001              Bandeja Oval Prata 50 x 32 (3)       10.0
# 162   T / 001  Banqueta Bistro Cromada Estof. Brancas (3)      100.0
# 165   T / 001                 Banqueta Bistro Madeira (3)       50.0
# ...       ...                                         ...        ...
# 1538  T / 001       Travessa Oval 51 Fracalanza Prata (3)        5.0
# 1558  T / 001                 Travessa Oval Prata Sal (3)        7.0
# 1666  T / 001           Xicara Cafe c\ Pires Pomerode (3)      100.0
# 1670   898679              Xicara Cafe c\ Pires Stand (3)      100.0
# 1672  T / 001            Xicara Cha c\ Pires Pomerode (3)      200.0
#
#       Categoria QTD Data
# 61    Terceiros
# 105   Terceiros
# 132   Terceiros
# 162   Terceiros
# 165   Terceiros
# ...

# %% [markdown]
# ### Agora vamos exportar a nova base de preços atualizada

# %%
# Passo 6: Salvar os novos preços dos produtos
df_new.to_excel("Produtos Novo.xlsx", index=False)

# %%
pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(5)

# Passo 6: Enviar por e-mail o resultado
pyautogui.click(x=109, y=183)

pyautogui.write("contato@provencefestas.com.br")
pyautogui.press("tab") # seleciona o email
# escreve outro email
# tab
# escreve outro email
# tab
pyautogui.press("tab") # pula pro campo de assunto
pyperclip.copy("Relatório Inventario")
pyautogui.hotkey("ctrl", "v") # escrever o assunto
pyautogui.press("tab") #pular pro corpo do email

texto = f"""
Prezados, bom dia

Segue envio do relatório de produtos para fazr o inventario

Abs
Henrique Cesar"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")

# clicar no botão enviar

# apertar Ctrl Enter
pyautogui.hotkey("ctrl", "enter")

# %%
#pyautogui.position()
# Out:
# Point(x=464, y=400)
